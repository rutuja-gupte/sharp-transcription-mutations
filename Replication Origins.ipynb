# %%
import pandas as pd

# %%
with open("ARS.txt") as f:
    data = f.read()

# %%
queries = len(list(set([i for i in data.split("\n") if i.startswith("ARS")])))

# %%
ori = pd.read_csv("rep_origins.csv")

# %%
ori
# Out:
#     ARS > Primary DBID ARS > Systematic Name ARS > Standard Name  \
# 0           S000007553               ARS1021                 NaN
# 1           S000007554               ARS1501                 NaN
# 2           S000007633                ARS601              ARS601
# 3           S000007634                ARS602              ARS602
# 4           S000007635                ARS603              ARS603
# ..                 ...                   ...                 ...
# 347         S000178111                ARS907                 NaN
# 348         S000178132               ARS1210                 NaN
# 349         S000178135             ARS1212.5                 NaN
# 350         S000178146               ARS1235                 NaN
# 351         S000178152             ARS1307.5                 NaN
#
#                             ARS > Name  ARS > Chromosome Location > End  \
# 0                                  NaN                           684098
# ...
